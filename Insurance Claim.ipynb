# %% [markdown]
# # Insurance Claim

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# As we can seee that our dataset is not having null values except column "_c39 " and we can drop this column as it wont impac t our predictions and also it has completely NaN values.

# %%
df = df.drop(columns = ['_c39'],axis = 1)

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... witnesses police_report_available total_claim_amount  \
# ...

# %% [markdown]
# Now we have 39 columns and we will see how the data has been distributed in a dataset and we will look into some relationship / comparison in visualization through plots/graphs for easy and better understanding.
#
# Also we have categorical and numerical data in our dataset.We will use histogram to view our numerical columns.

# %% [markdown]
# # EDA

# %%
sns.set_theme()
df.hist(bins = 20, figsize = (20,20))
plt.show()

# %% [markdown]
# Policy number columns has distributed uniformly.
#
# capital loss and capital gain has some skewed towards left and right side.
#
# numbers of vehicles involved, bodily injuries, witnesses columns has values of 0-4 and not in continous range and from thois we can see that mostly 1 vehicles involved in incident and minimum 1 witness are there who witnessed the incident.
#
# total claim amount,injury claim, property claim , vehicle claim, policy annual premium has normally distributed and we can see mild outliers on vehicle claim on lower side.
#
# umbrella limit columns has skewed more on right side and it has 0 for most of the customers.
#
# policy deductable has fixed amount of 500,1000,2000 and mostly they are deducting 1000 for the policy and based on insurance which customers availed.
#
# We will see how the remaining columns of categorical data distributed in dataset through bar plot / countplot.

# %%
df['policy_state'].value_counts()
# Out:
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64

# %%
sns.countplot(df['policy_state'])
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='count'>

# %% [markdown]
# Customers insured for insurance in State OH and IL

# %%
df['insured_sex'].value_counts()
# Out:
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %%
sns.countplot(df['insured_sex'])
# Out:
# <AxesSubplot:xlabel='insured_sex', ylabel='count'>

# %%
df['insured_education_level'].value_counts()
# Out:
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64

# %%
sns.countplot(df['insured_education_level'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['insured_occupation'].value_counts()
# Out:
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# priv-house-serv      71
# other-service        71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64

# %%
sns.countplot(df['insured_occupation'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %% [markdown]
# Most of the customers are belongs to the occupation " machine-op-inspct " and " prof-specialty " who has taken this insurance.

# %%
df['insured_hobbies'].value_counts()
# Out:
# reading           64
# paintball         57
# exercise          57
# bungie-jumping    56
# camping           55
# movies            55
# golf              55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64

# %%
sns.countplot(df['insured_hobbies'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['incident_type'].value_counts()
# Out:
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64

# %%
sns.countplot(df['incident_type'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['incident_date'].value_counts()
# Out:
# 02-02-2015    28
# 17-02-2015    26
# 07-01-2015    25
# 24-01-2015    24
# 04-02-2015    24
# 10-01-2015    24
# 19-01-2015    23
# 08-01-2015    22
# 13-01-2015    21
# 30-01-2015    21
# 31-01-2015    20
# 12-02-2015    20
# 06-02-2015    20
# 22-02-2015    20
# 14-01-2015    19
# 12-01-2015    19
# 01-01-2015    19
# 23-02-2015    19
# 21-02-2015    19
# 21-01-2015    19
# 14-02-2015    18
# 28-02-2015    18
# 18-01-2015    18
# 20-01-2015    18
# 03-01-2015    18
# 01-02-2015    18
# 25-02-2015    18
# 08-02-2015    17
# 26-02-2015    17
# 09-01-2015    17
# 24-02-2015    17
# 06-01-2015    17
# 13-02-2015    16
# 16-02-2015    16
# 15-02-2015    16
# 05-02-2015    16
# 16-01-2015    16
# 17-01-2015    15
# 15-01-2015    15
# 28-01-2015    15
# 18-02-2015    15
# 22-01-2015    14
# 20-02-2015    14
# 27-02-2015    14
# 23-01-2015    13
# 27-01-2015    13
# 09-02-2015    13
# 03-02-2015    13
# 01-03-2015    12
# 04-01-2015    12
# 29-01-2015    11
# 26-01-2015    11
# ...

# %%
plt.figure(figsize=(20, 10))
sns.countplot(df['incident_date'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %% [markdown]
# More number of fraud has been reported on February Month of 2015 as per the above plot in terms of incident date.

# %%
df['collision_type'].value_counts()
# Out:
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: collision_type, dtype: int64

# %%
sns.countplot(df['collision_type'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['incident_severity'].value_counts()
# Out:
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64

# %%
sns.countplot(df['incident_severity'])
# Out:
# <AxesSubplot:xlabel='incident_severity', ylabel='count'>

# %%
df['authorities_contacted'].value_counts()
# Out:
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64

# %%
sns.countplot(df['authorities_contacted'])
# Out:
# <AxesSubplot:xlabel='authorities_contacted', ylabel='count'>

# %%
df['police_report_available'].value_counts()
# Out:
# ?      343
# NO     343
# YES    314
# Name: police_report_available, dtype: int64

# %%
sns.countplot(df['police_report_available'])
# Out:
# <AxesSubplot:xlabel='police_report_available', ylabel='count'>

# %% [markdown]
# Here it is showing that police report for most of the incident is not available and not given for claiming the insurance.

# %%
df['incident_state'].value_counts()
# Out:
# NY    262
# SC    248
# WV    217
# NC    110
# VA    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64

# %%
sns.countplot(df['incident_state'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['incident_city'].value_counts()
# Out:
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64

# %%
sns.countplot(df['incident_city'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %% [markdown]
# all most all are more avail insurance claims but Springfield city reported more for availing the insurance claims.

# %%
df['property_damage'].value_counts()
# Out:
# ?      360
# NO     338
# YES    302
# Name: property_damage, dtype: int64

# %%
sns.countplot(df['property_damage'])
# Out:
# <AxesSubplot:xlabel='property_damage', ylabel='count'>

# %% [markdown]
# There is no property damage happened to avail property claims and most of the case it is not known from the above plot.

# %%
df['bodily_injuries'].value_counts()
# Out:
# 0    340
# 2    332
# 1    328
# Name: bodily_injuries, dtype: int64

# %%
sns.countplot(df['bodily_injuries'])
# Out:
# <AxesSubplot:xlabel='bodily_injuries', ylabel='count'>

# %% [markdown]
# it is clear that not much injury on body and it is 1 or 2 places.

# %%
df['total_claim_amount'].value_counts()
# Out:
# 59400    5
# 75400    4
# 60600    4
# 2640     4
# 58500    4
#         ..
# 57970    1
# 41580    1
# 45180    1
# 3690     1
# 71680    1
# Name: total_claim_amount, Length: 763, dtype: int64

# %%
df.groupby('insured_hobbies').total_claim_amount.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='insured_hobbies'>

# %% [markdown]
# Customer who has hobby as "reading" has insured more claim amount of > 60.

# %%
df['auto_make'].value_counts()
# Out:
# Dodge         80
# Suburu        80
# Saab          80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64

# %%
sns.countplot(df['auto_make'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['auto_model'].value_counts()
# Out:
# RAM               43
# Wrangler          42
# Neon              37
# A3                37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# Camry             28
# 92x               28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# Grand Cherokee    25
# 93                25
# Maxima            24
# Escape            24
# Tahoe             24
# X5                23
# Ultima            23
# Silverado         22
# Civic             22
# Highlander        22
# Fusion            21
# CRV               20
# Corolla           20
# Impreza           20
# ML350             20
# TL                20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64

# %%
plt.figure(figsize=(20, 10))
sns.countplot(df['auto_model'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %%
df['auto_year'].value_counts()
# Out:
# 1995    56
# 1999    55
# 2005    54
# 2011    53
# 2006    53
# 2007    52
# 2003    51
# 2010    50
# 2009    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: auto_year, dtype: int64

# %%
sns.countplot(df['auto_year'])
plt.xticks(rotation = 60)
plt.tight_layout()

# %% [markdown]
# Most of the automobile model which is claiming insurance is RAM && WRANGLER. Most of the vehicle manufacture year is 1995, 1999 and 2005-2007 who is availing vehicle claim insurance.

# %%
df['collision_type'] = df['collision_type'].str.strip().replace({'?': 'Unknown'})
df['police_report_available'] = df['police_report_available'].str.strip().replace({'?': 'Unknown'})

# %%
num_col = df.select_dtypes(exclude = object)
cat_col = df.select_dtypes(include = object)

# %%
num_col
# Out:
#      months_as_customer  age  policy_number  policy_deductable  \
# 0                   328   48         521585               1000
# 1                   228   42         342868               2000
# 2                   134   29         687698               2000
# 3                   256   41         227811               2000
# 4                   228   44         367455               1000
# ..                  ...  ...            ...                ...
# 995                   3   38         941851               1000
# 996                 285   41         186934               1000
# 997                 130   34         918516                500
# 998                 458   62         533940               2000
# 999                 456   60         556080               1000
#
#      policy_annual_premium  umbrella_limit  insured_zip  capital-gains  \
# 0                  1406.91               0       466132          53300
# ...

# %%
num_col = num_col.drop(columns = ['total_claim_amount','months_as_customer'],axis =1)
num_col
# Out:
#      age  policy_number  policy_deductable  policy_annual_premium  \
# 0     48         521585               1000                1406.91
# 1     42         342868               2000                1197.22
# 2     29         687698               2000                1413.14
# 3     41         227811               2000                1415.74
# 4     44         367455               1000                1583.91
# ..   ...            ...                ...                    ...
# 995   38         941851               1000                1310.80
# 996   41         186934               1000                1436.79
# 997   34         918516                500                1383.49
# 998   62         533940               2000                1356.92
# 999   60         556080               1000                 766.19
#
#      umbrella_limit  insured_zip  capital-gains  capital-loss  \
# 0                 0       466132          53300             0
# ...

# %%
cat_col
# Out:
#     policy_bind_date policy_state policy_csl insured_sex  \
# 0         17-10-2014           OH    250/500        MALE
# 1         27-06-2006           IN    250/500        MALE
# 2         06-09-2000           OH    100/300      FEMALE
# 3         25-05-1990           IL    250/500      FEMALE
# 4         06-06-2014           IL   500/1000        MALE
# ..               ...          ...        ...         ...
# 995       16-07-1991           OH   500/1000      FEMALE
# 996       05-01-2014           IL    100/300      FEMALE
# 997       17-02-2003           OH    250/500      FEMALE
# 998       18-11-2011           IL   500/1000        MALE
# 999       11-11-1996           OH    250/500      FEMALE
#
#     insured_education_level insured_occupation insured_hobbies  \
# 0                        MD       craft-repair        sleeping
# 1                        MD  machine-op-inspct         reading
# 2                       PhD              sales     board-games
# ...

# %%
cat_col.columns
# Out:
# Index(['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'incident_date', 'incident_type',
#        'collision_type', 'incident_severity', 'authorities_contacted',
#        'incident_state', 'incident_city', 'incident_location',
#        'property_damage', 'police_report_available', 'auto_make', 'auto_model',
#        'fraud_reported'],
#       dtype='object')

# %% [markdown]
# We have Policy start date/ month/ year and incident day/month/year.So I am separating day , month, year from policy start date and taking only day and month from incident reported as all the reported incidents happened in 2015 using Pandas Datetime Function.

# %%
cat_col['policy_bind_day'] = pd.to_datetime(cat_col['policy_bind_date']).dt.day
cat_col['policy_bind_month'] = pd.to_datetime(cat_col['policy_bind_date']).dt.month
cat_col['policy_bind_year'] = pd.to_datetime(cat_col['policy_bind_date']).dt.year
cat_col['incident_day'] = pd.to_datetime(cat_col['incident_date']).dt.day
cat_col['incident_month'] = pd.to_datetime(cat_col['incident_date']).dt.month

# %%
cat_col  = cat_col.drop(columns = ['policy_bind_date','incident_date'],axis = 1)
cat_col
# Out:
#     policy_state policy_csl insured_sex insured_education_level  \
# 0             OH    250/500        MALE                      MD
# 1             IN    250/500        MALE                      MD
# 2             OH    100/300      FEMALE                     PhD
# 3             IL    250/500      FEMALE                     PhD
# 4             IL   500/1000        MALE               Associate
# ..           ...        ...         ...                     ...
# 995           OH   500/1000      FEMALE                 Masters
# 996           IL    100/300      FEMALE                     PhD
# 997           OH    250/500      FEMALE                 Masters
# 998           IL   500/1000        MALE               Associate
# 999           OH    250/500      FEMALE               Associate
#
#     insured_occupation insured_hobbies insured_relationship  \
# 0         craft-repair        sleeping              husband
# 1    machine-op-inspct         reading       other-relative
# ...

# %% [markdown]
# Applying Label Encoder encoding tech niques to convert categorical data into numerical data

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
cols = ['policy_state', 'policy_csl', 'insured_sex', 'insured_education_level','insured_occupation', 'insured_hobbies', 'insured_relationship',
       'incident_type', 'collision_type', 'incident_severity','authorities_contacted', 'incident_state', 'incident_city',
       'incident_location', 'property_damage', 'police_report_available','auto_make', 'auto_model', 'fraud_reported']

for i in cols:
    cat_col[cols]= cat_col[cols].apply(labelencoder.fit_transform)

# %%
cat_col.head()
# Out:
#    policy_state  policy_csl  insured_sex  insured_education_level  \
# 0             2           1            1                        4
# 1             1           1            1                        4
# 2             2           0            0                        6
# 3             0           1            0                        6
# 4             0           2            1                        0
#
#    insured_occupation  insured_hobbies  insured_relationship  incident_type  \
# 0                   2               17                     0              2
# 1                   6               15                     2              3
# 2                  11                2                     3              0
# 3                   1                2                     4              2
# 4                  11                2                     4              3
#
#    collision_type  incident_severity  ...  property_damage  \
# ...

# %%
num_col.describe()
# Out:
#                age  policy_number  policy_deductable  policy_annual_premium  \
# count  1000.000000    1000.000000        1000.000000            1000.000000
# mean     38.948000  546238.648000        1136.000000            1256.406150
# std       9.140287  257063.005276         611.864673             244.167395
# min      19.000000  100804.000000         500.000000             433.330000
# 25%      32.000000  335980.250000         500.000000            1089.607500
# 50%      38.000000  533135.000000        1000.000000            1257.200000
# 75%      44.000000  759099.750000        2000.000000            1415.695000
# max      64.000000  999435.000000        2000.000000            2047.590000
#
#        umbrella_limit    insured_zip  capital-gains   capital-loss  \
# count    1.000000e+03    1000.000000    1000.000000    1000.000000
# mean     1.101000e+06  501214.488000   25126.100000  -26793.700000
# std      2.297407e+06   71701.610941   27872.187708   28104.096686
# ...

# %%
plt.figure(figsize = (20,20))
pltnumber = 1

for column in num_col:
    if pltnumber<=24:
        ax = plt.subplot(6,4,pltnumber)
        sns.distplot(num_col[column])
        plt.xlabel(column,fontsize=10)
        pltnumber+=1
plt.tight_layout()

# %% [markdown]
# there is skewness in the data

# %%
plt.figure(figsize = (20,20))
pltnumber = 1

for column in num_col:
    if pltnumber<=24:
        ax = plt.subplot(6,4,pltnumber)
        sns.boxplot(num_col[column])
        plt.xlabel(column,fontsize=10)
        pltnumber+=1
plt.tight_layout()

# %% [markdown]
# There are some outliers in the data

# %%
num_col.skew()
# Out:
# age                            0.478988
# policy_number                  0.038991
# policy_deductable              0.477887
# policy_annual_premium          0.004402
# umbrella_limit                 1.806712
# insured_zip                    0.816554
# capital-gains                  0.478850
# capital-loss                  -0.391472
# incident_hour_of_the_day      -0.035584
# number_of_vehicles_involved    0.502664
# bodily_injuries                0.014777
# witnesses                      0.019636
# injury_claim                   0.264811
# property_claim                 0.378169
# vehicle_claim                 -0.621098
# auto_year                     -0.048289
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(num_col.corr(),cmap = 'ocean', annot=True, linewidths=.5, ax=ax)
plt.show()

# %%
df = pd.concat([num_col,cat_col],axis = 1)
df
# Out:
#      age  policy_number  policy_deductable  policy_annual_premium  \
# 0     48         521585               1000                1406.91
# 1     42         342868               2000                1197.22
# 2     29         687698               2000                1413.14
# 3     41         227811               2000                1415.74
# 4     44         367455               1000                1583.91
# ..   ...            ...                ...                    ...
# 995   38         941851               1000                1310.80
# 996   41         186934               1000                1436.79
# 997   34         918516                500                1383.49
# 998   62         533940               2000                1356.92
# 999   60         556080               1000                 766.19
#
#      umbrella_limit  insured_zip  capital-gains  capital-loss  \
# 0                 0       466132          53300             0
# ...

# %%
X = df.drop(columns = ['fraud_reported','umbrella_limit'],axis = 1)
y = df['fraud_reported']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
x.head()
# Out:
#         age  policy_number  policy_deductable  policy_annual_premium  \
# 0  0.990836      -0.095953          -0.222383               0.616705
# 1  0.334073      -0.791527           1.412784              -0.242521
# 2 -1.088913       0.550566           1.412784               0.642233
# 3  0.224613      -1.239334           1.412784               0.652886
# 4  0.552994      -0.695834          -0.222383               1.341980
#
#    insured_zip  capital-gains  capital-loss  incident_hour_of_the_day  \
# 0    -0.489529       1.011331      0.953851                 -0.956261
# 1    -0.461008      -0.901927      0.953851                 -0.524475
# 2    -0.984885       0.358023      0.953851                 -0.668404
# 3     1.491682       0.853388     -1.267577                 -0.956261
# 4     1.527808       1.467210     -0.683741                  1.202666
#
#    number_of_vehicles_involved  bodily_injuries  ...  incident_location  \
# ...

# %%
y.value_counts()
# Out:
# 0    753
# 1    247
# Name: fraud_reported, dtype: int64

# %% [markdown]
# # Data Imbalanced

# %%
sns.countplot(df['fraud_reported'])
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x , y = SM.fit_resample(x,y)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='fraud_reported', ylabel='count'>

# %%
y.value_counts()
# Out:
# 1    753
# 0    753
# Name: fraud_reported, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,classification_report
import scikitplot as skplt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score,roc_curve

# %%
#train_test split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.25, random_state = 128)

# %%
#check the shape of train test split
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1129, 38), (377, 38), (1129,), (377,))

# %%
#Train result
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred =KNN .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#Test result
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred =KNN .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.42      0.59       564
#            1       0.63      1.00      0.77       565
#
#     accuracy                           0.71      1129
#    macro avg       0.81      0.71      0.68      1129
# weighted avg       0.81      0.71      0.68      1129
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.90      0.30      0.45       189
#            1       0.58      0.97      0.72       188
#
#     accuracy                           0.63       377
#    macro avg       0.74      0.63      0.58       377
# weighted avg       0.74      0.63      0.58       377
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",KNN.score(x_train,y_train))
print("Test accuracy::",KNN.score(x_test,y_test))
# Out:
# Training accuracy:: 0.7068201948627104
# Test accuracy:: 0.6312997347480106

# %%
print(cross_val_score(KNN,x,y,cv=5).mean())
# Out:
# 0.6381245737167498

# %%
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr,color ='red',label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE KNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 63.22%

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
y_pred =RFC .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
y_pred =RFC .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       564
#            1       1.00      1.00      1.00       565
#
#     accuracy                           1.00      1129
#    macro avg       1.00      1.00      1.00      1129
# weighted avg       1.00      1.00      1.00      1129
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88       189
#            1       0.86      0.90      0.88       188
#
#     accuracy                           0.88       377
#    macro avg       0.88      0.88      0.88       377
# weighted avg       0.88      0.88      0.88       377
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",RFC.score(x_train,y_train))
print("Test accuracy::",RFC.score(x_test,y_test))
# Out:
# Training accuracy:: 1.0
# Test accuracy:: 0.8779840848806366

# %%
print(cross_val_score(RFC,x,y,cv=5).mean())
# Out:
# 0.8692658027326132

# %%
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr,color ='blue',label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 87.81%

# %%
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(x_train, y_train)
y_pred =DecisionTree .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))

#test result
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(x_train, y_train)
y_pred =DecisionTree .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       564
#            1       1.00      1.00      1.00       565
#
#     accuracy                           1.00      1129
#    macro avg       1.00      1.00      1.00      1129
# weighted avg       1.00      1.00      1.00      1129
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       189
#            1       0.83      0.84      0.83       188
#
#     accuracy                           0.83       377
#    macro avg       0.83      0.83      0.83       377
# weighted avg       0.83      0.83      0.83       377
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",DecisionTree.score(x_train,y_train))
print("Test accuracy::",DecisionTree.score(x_test,y_test))
# Out:
# Training accuracy:: 1.0
# Test accuracy:: 0.830238726790451

# %%
print(cross_val_score(DecisionTree,x,y,cv=5).mean())
# Out:
# 0.8134606499306946

# %%
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr,color ='blue',label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE DecisionTree')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 83.03%

# %% [markdown]
# # ENSEMBLE TECHNIQUES

# %%
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_pred =adb .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_pred =adb .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       564
#            1       0.90      0.88      0.89       565
#
#     accuracy                           0.89      1129
#    macro avg       0.89      0.89      0.89      1129
# weighted avg       0.89      0.89      0.89      1129
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       189
#            1       0.87      0.88      0.87       188
#
#     accuracy                           0.87       377
#    macro avg       0.87      0.87      0.87       377
# weighted avg       0.87      0.87      0.87       377
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",adb.score(x_train,y_train))
print("Test accuracy::",adb.score(x_test,y_test))
# Out:
# Training accuracy:: 0.8945969884853853
# Test accuracy:: 0.8726790450928382

# %%
print(cross_val_score(adb,x,y,cv=5).mean())
# Out:
# 0.848696398319069

# %%
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr,color ='orange',label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE adb')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 87.27000000000001%

# %%
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
y_pred =gbc .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print( skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
y_pred =gbc .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print( skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96       564
#            1       0.96      0.97      0.96       565
#
#     accuracy                           0.96      1129
#    macro avg       0.96      0.96      0.96      1129
# weighted avg       0.96      0.96      0.96      1129
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       189
#            1       0.86      0.90      0.88       188
#
#     accuracy                           0.88       377
#    macro avg       0.88      0.88      0.88       377
# weighted avg       0.88      0.88      0.88       377
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",gbc.score(x_train,y_train))
print("Test accuracy::",gbc.score(x_test,y_test))
# Out:
# Training accuracy:: 0.9645704162976085
# Test accuracy:: 0.8753315649867374

# %%
print(cross_val_score(gbc,x,y,cv=5).mean())
# Out:
# 0.8805482827660558

# %%
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr,color ='red',label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE gbc')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 87.53999999999999%

# %% [markdown]
# The Score for the ROC AUC Curve is : 88.87%
# Checking the f1 score accuracy and cross validation score of each model and the model which is having less difference is considered as best model.
#
# Here the best model is RandomForestClassifier model.
#
# Applying Hyper parameter tuning

# %% [markdown]
# # Hyper Parameter Tuning

# %%
params ={'max_depth':list(range(200,400,50)),
         'n_estimators':list(range(10,120,20)),
         'max_features': ['auto', 'sqrt', 'log2'], 
         'criterion' : ['gini','entropy'],
         }

# %%
grid_search=GridSearchCV(RFC,params,verbose=4,refit=True,cv = 5,n_jobs = -1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [200, 250, 300, 350],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 30, 50, 70, 90, 110]},
#              verbose=4)

# %%
final_model=grid_search.best_estimator_
final_model
# Out:
# RandomForestClassifier(max_depth=250, max_features='log2', n_estimators=50)

# %%
final_model=grid_search.best_params_
print(final_model)
# Out:
# {'criterion': 'gini', 'max_depth': 250, 'max_features': 'log2', 'n_estimators': 50}

# %%
final_model=grid_search.best_score_
print(final_model)
# Out:
# 0.8769046214355949

# %%
final_model = RandomForestClassifier(n_estimators=90 , criterion = 'entropy', max_depth = 350, max_features = 'auto')
final_model.fit(x_train,y_train)
final_model.score(x_test,y_test)
# Out:
# 0.8620689655172413

# %%
y_pred=final_model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8620689655172413

# %%
skplt.metrics.plot_confusion_matrix(y_test,y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
fpr, tpr, _= roc_curve(y_test, y_pred)
auc_score = roc_auc_score(y_test, y_pred)
plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr, tpr,color ='red',label="auc="+str(auc_score))
plt.box(True)
plt.title('ROC CURVE RFC')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc=4)
plt.grid(True)
plt.show()
print('The Score for the ROC AUC Curve is : {}%'.format(round(auc_score,4)*100))
# Out:
# The Score for the ROC AUC Curve is : 86.21%

# %% [markdown]
# So after hyper parameter my accuracy model is increased

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(final_model,"Insurance_Claims_Fraud_Detection")
# Out:
# ['Insurance_Claims_Fraud_Detection']
