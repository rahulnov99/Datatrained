# %% [markdown]
# # Global Power Plant

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Global Power Plant.csv')

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 903     IND        India                  YERMARUS TPP  IND0000513
# 904     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 905     IND        India  Yelisirur wind power project  WRI1026776
# 906     IND        India                   ZAWAR MINES  WRI1019901
# 907     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# 1           98.0   24.7663    74.6090         Coal         NaN         NaN
# 2           39.2   21.9038    69.3732         Wind         NaN         NaN
# 3          135.0   23.8712    91.3602          Gas         NaN         NaN
# 4         1800.0   21.9603    82.4091         Coal         Oil         NaN
# ..           ...       ...        ...          ...         ...         ...
# 903       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 904          3.0   12.8932    78.1654        Solar         NaN         NaN
# 905         25.5   15.2758    75.5811         Wind         NaN         NaN
# 906         80.0   24.3500    73.7477         Coal         NaN         NaN
# 907         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...                    geolocation_source  wepp_id year_of_capacity_data  \
# 0    ...  National Renewable Energy Laboratory      NaN                   NaN
# 1    ...                                   WRI      NaN                   NaN
# 2    ...                                   WRI      NaN                   NaN
# 3    ...                                   WRI      NaN                2018.0
# 4    ...                                   WRI      NaN                2018.0
# ..   ...                                   ...      ...                   ...
# 903  ...                                   WRI      NaN                2018.0
# 904  ...                        Industry About      NaN                   NaN
# 905  ...                                   WRI      NaN                   NaN
# 906  ...                                   WRI      NaN                   NaN
# 907  ...                                   WRI      NaN                   NaN
#
#     generation_gwh_2013 generation_gwh_2014 generation_gwh_2015  \
# 0                   NaN                 NaN                 NaN
# 1                   NaN                 NaN                 NaN
# 2                   NaN                 NaN                 NaN
# 3            631.777928          617.789264          843.747000
# 4           1668.290000         3035.550000         5916.370000
# ..                  ...                 ...                 ...
# 903                 NaN                 NaN            0.994875
# 904                 NaN                 NaN                 NaN
# 905                 NaN                 NaN                 NaN
# 906                 NaN                 NaN                 NaN
# 907                 NaN                 NaN                 NaN
#
#      generation_gwh_2016  generation_gwh_2017         generation_data_source  \
# 0                    NaN                  NaN                            NaN
# 1                    NaN                  NaN                            NaN
# 2                    NaN                  NaN                            NaN
# 3             886.004428           663.774500  Central Electricity Authority
# 4            6243.000000          5385.579736  Central Electricity Authority
# ..                   ...                  ...                            ...
# 903           233.596650           865.400000  Central Electricity Authority
# 904                  NaN                  NaN                            NaN
# 905                  NaN                  NaN                            NaN
# 906                  NaN                  NaN                            NaN
# 907                  NaN                  NaN                            NaN
#
#      estimated_generation_gwh
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 903                       NaN
# 904                       NaN
# 905                       NaN
# 906                       NaN
# 907                       NaN
#
# [908 rows x 25 columns]

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#                      geolocation_source  wepp_id year_of_capacity_data  \
# 0  National Renewable Energy Laboratory      NaN                   NaN
# 1                                   WRI      NaN                   NaN
# 2                                   WRI      NaN                   NaN
# 3                                   WRI      NaN                2018.0
# 4                                   WRI      NaN                2018.0
#
#   generation_gwh_2013 generation_gwh_2014 generation_gwh_2015  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3          631.777928          617.789264             843.747
# 4         1668.290000         3035.550000            5916.370
#
#    generation_gwh_2016  generation_gwh_2017         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           886.004428           663.774500  Central Electricity Authority
# 4          6243.000000          5385.579736  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (908, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908 entries, 0 to 907
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   908 non-null    object
#  1   country_long              908 non-null    object
#  2   name                      908 non-null    object
#  3   gppd_idnr                 908 non-null    object
#  4   capacity_mw               908 non-null    float64
#  5   latitude                  862 non-null    float64
#  6   longitude                 862 non-null    float64
#  7   primary_fuel              908 non-null    object
#  8   other_fuel1               199 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        528 non-null    float64
#  12  owner                     342 non-null    object
#  13  source                    908 non-null    object
#  14  url                       908 non-null    object
#  15  geolocation_source        889 non-null    object
#  16  wepp_id                   0 non-null      float64
#  17  year_of_capacity_data     520 non-null    float64
#  18  generation_gwh_2013       384 non-null    float64
#  19  generation_gwh_2014       401 non-null    float64
#  20  generation_gwh_2015       425 non-null    float64
#  21  generation_gwh_2016       437 non-null    float64
#  22  generation_gwh_2017       443 non-null    float64
#  23  generation_data_source    450 non-null    object
#  24  estimated_generation_gwh  0 non-null      float64
# dtypes: float64(13), object(12)
# memory usage: 177.5+ KB

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   908.000000  862.000000  862.000000          0.0          528.000000
# mean    321.046378   21.196189   77.447848          NaN         1996.876894
# std     580.221767    6.248627    4.907260          NaN           17.047817
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.837500   16.771575   74.258975          NaN         1988.000000
# 50%      60.000000   21.778300   76.719250          NaN         2000.000000
# 75%     388.125000   25.516375   79.441475          NaN         2011.250000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  520.0           384.000000
# mean       NaN                 2018.0          2304.059202
# std        NaN                    0.0          3794.767492
# min        NaN                 2018.0             0.000000
# 25%        NaN                 2018.0           244.458088
# 50%        NaN                 2018.0           797.063475
# 75%        NaN                 2018.0          2795.021500
# max        NaN                 2018.0         27586.200000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           401.000000           425.000000           437.000000
# mean           2420.393316          2414.072373          2453.936292
# std            4013.558173          4183.203199          4152.038216
# min               0.000000             0.000000             0.000000
# 25%             223.650436           174.174750           187.193669
# 50%             805.760000           701.027250           716.728350
# 75%            3034.575000          3080.000000          3263.483000
# max           28127.000000         30539.000000         30015.000000
#
#        generation_gwh_2017  estimated_generation_gwh
# count           443.000000                       0.0
# mean           2531.754458                       NaN
# std            4187.236364                       NaN
# min               0.000000                       NaN
# 25%             177.643170                       NaN
# 50%             807.601700                       NaN
# 75%            3258.785000                       NaN
# max           35116.000000                       NaN

# %% [markdown]
# We can see that there are more null values present in dataset now find null values using isnull function method.

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  other_fuel3  commissioning_year  \
# count   908.000000  862.000000  862.000000          0.0          528.000000
# mean    321.046378   21.196189   77.447848          NaN         1996.876894
# std     580.221767    6.248627    4.907260          NaN           17.047817
# min       0.000000    8.168900   68.644700          NaN         1927.000000
# 25%      16.837500   16.771575   74.258975          NaN         1988.000000
# 50%      60.000000   21.778300   76.719250          NaN         2000.000000
# 75%     388.125000   25.516375   79.441475          NaN         2011.250000
# max    4760.000000   34.649000   95.408000          NaN         2018.000000
#
#        wepp_id  year_of_capacity_data  generation_gwh_2013  \
# count      0.0                  520.0           384.000000
# mean       NaN                 2018.0          2304.059202
# std        NaN                    0.0          3794.767492
# min        NaN                 2018.0             0.000000
# 25%        NaN                 2018.0           244.458088
# 50%        NaN                 2018.0           797.063475
# 75%        NaN                 2018.0          2795.021500
# max        NaN                 2018.0         27586.200000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count           401.000000           425.000000           437.000000
# mean           2420.393316          2414.072373          2453.936292
# std            4013.558173          4183.203199          4152.038216
# min               0.000000             0.000000             0.000000
# 25%             223.650436           174.174750           187.193669
# 50%             805.760000           701.027250           716.728350
# 75%            3034.575000          3080.000000          3263.483000
# max           28127.000000         30539.000000         30015.000000
#
#        generation_gwh_2017  estimated_generation_gwh
# count           443.000000                       0.0
# mean           2531.754458                       NaN
# std            4187.236364                       NaN
# min               0.000000                       NaN
# 25%             177.643170                       NaN
# 50%             807.601700                       NaN
# 75%            3258.785000                       NaN
# max           35116.000000                       NaN

# %% [markdown]
# here .describe shows the mean,counts ,min,max,quantile values of each column of numerical values. there are so many missing values are present in the dataset we have 13 numerical and 12 objects columns

# %% [markdown]
# # Data Cleaning

# %%
df.nunique()
# Out:
# country                       1
# country_long                  1
# name                        908
# gppd_idnr                   908
# capacity_mw                 365
# latitude                    837
# longitude                   828
# primary_fuel                  8
# other_fuel1                   3
# other_fuel2                   1
# other_fuel3                   0
# commissioning_year           73
# owner                       280
# source                      191
# url                         304
# geolocation_source            3
# wepp_id                       0
# year_of_capacity_data         1
# generation_gwh_2013         364
# generation_gwh_2014         374
# generation_gwh_2015         398
# generation_gwh_2016         405
# generation_gwh_2017         410
# generation_data_source        1
# estimated_generation_gwh      0
# dtype: int64

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 907
# other_fuel3                 908
# commissioning_year          380
# owner                       566
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# generation_data_source      458
# estimated_generation_gwh    908
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# there are bulk of null values to solve in a datset Now separate numeric and categorical variables

# %%
num_col = df.select_dtypes(include=[np.number])
cat_col = df.select_dtypes(exclude=[np.number])

# %%
num_col.isnull().sum()
# Out:
# capacity_mw                   0
# latitude                     46
# longitude                    46
# other_fuel3                 908
# commissioning_year          380
# wepp_id                     908
# year_of_capacity_data       388
# generation_gwh_2013         524
# generation_gwh_2014         507
# generation_gwh_2015         483
# generation_gwh_2016         471
# generation_gwh_2017         465
# estimated_generation_gwh    908
# dtype: int64

# %% [markdown]
# see seperated missing null numerical columns
#
# "other_fuel3","wepp_id","estimated_generation_gwh" has no values at all so we can drop these columns

# %%
num_col = num_col.drop(columns = ['other_fuel3','wepp_id','estimated_generation_gwh'],axis = 1)
num_col
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090                 NaN
# 2           39.2   21.9038    69.3732                 NaN
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 903       1600.0   16.2949    77.3568              2016.0
# 904          3.0   12.8932    78.1654                 NaN
# 905         25.5   15.2758    75.5811                 NaN
# 906         80.0   24.3500    73.7477                 NaN
# 907         16.5    9.9344    77.4768                 NaN
#
#      year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# 2                      NaN                  NaN                  NaN
# 3                   2018.0           631.777928           617.789264
# 4                   2018.0          1668.290000          3035.550000
# ..                     ...                  ...                  ...
# 903                 2018.0                  NaN                  NaN
# 904                    NaN                  NaN                  NaN
# 905                    NaN                  NaN                  NaN
# 906                    NaN                  NaN                  NaN
# 907                    NaN                  NaN                  NaN
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3             843.747000           886.004428           663.774500
# 4            5916.370000          6243.000000          5385.579736
# ..                   ...                  ...                  ...
# 903             0.994875           233.596650           865.400000
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
# 907                  NaN                  NaN                  NaN
#
# [908 rows x 10 columns]

# %% [markdown]
# Fill the null values with mean() and mode() values
#
# year_of_capacity_data is a one unique value we can do drop it

# %%
num_col = num_col.drop(columns = ['year_of_capacity_data'],axis = 1)

# %%
num_col['latitude'] = num_col['latitude'].fillna(num_col['latitude'].mode()[0])

num_col['longitude'] = num_col['longitude'].fillna(num_col['longitude'].mode()[0])

num_col['commissioning_year'] = num_col['commissioning_year'].fillna(num_col['commissioning_year'].mode()[0])

num_col['generation_gwh_2013'] = num_col['generation_gwh_2013'].fillna(num_col['generation_gwh_2013'].mean())

num_col['generation_gwh_2014'] = num_col['generation_gwh_2014'].fillna(num_col['generation_gwh_2014'].mean())

num_col['generation_gwh_2015'] = num_col['generation_gwh_2015'].fillna(num_col['generation_gwh_2015'].mean())

num_col['generation_gwh_2016'] = num_col['generation_gwh_2016'].fillna(num_col['generation_gwh_2016'].mean())

num_col['generation_gwh_2017'] = num_col['generation_gwh_2017'].fillna(num_col['generation_gwh_2017'].mean())

# %% [markdown]
# Mode is used when the data having more occurences of more frequent value here top 4 columns are frequent values And one more thing Mode also replace with categorical values only now we have null values of categorical too now let's do that before we check our after treated nullvalues filled or not

# %%
num_col.isnull().sum()
# Out:
# capacity_mw            0
# latitude               0
# longitude              0
# commissioning_year     0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# dtype: int64

# %%
cat_col.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# primary_fuel                0
# other_fuel1               709
# other_fuel2               907
# owner                     566
# source                      0
# url                         0
# geolocation_source         19
# generation_data_source    458
# dtype: int64

# %%
cat_col = cat_col.drop(columns = ['other_fuel1','other_fuel2','country','name','owner','url','country_long','generation_data_source'],axis = 1)

# %%
#find missing values using mode
cat_col['geolocation_source'] = cat_col['geolocation_source'].fillna(cat_col['geolocation_source'].mode()[0])

# %%
cat_col.isnull().sum()
# Out:
# gppd_idnr             0
# primary_fuel          0
# source                0
# geolocation_source    0
# dtype: int64

# %%
cat_col.head()
# Out:
#     gppd_idnr primary_fuel                                source  \
# 0  WRI1020239        Solar  National Renewable Energy Laboratory
# 1  WRI1019881         Coal                  Ultratech Cement ltd
# 2  WRI1026669         Wind                                   CDM
# 3  IND0000001          Gas         Central Electricity Authority
# 4  IND0000002         Coal         Central Electricity Authority
#
#                      geolocation_source
# 0  National Renewable Energy Laboratory
# 1                                   WRI
# 2                                   WRI
# 3                                   WRI
# 4                                   WRI

# %% [markdown]
# here our data looks in categorical columns now data we will convert into numerical data.
#
# so now do change categorical into numerical using labelencoder method

# %%
df1 = pd.concat([num_col,cat_col],axis = 1)
df1.head()
# Out:
#    capacity_mw  latitude  longitude  commissioning_year  generation_gwh_2013  \
# 0          2.5   28.1839    73.2407              2011.0          2304.059202
# 1         98.0   24.7663    74.6090              2013.0          2304.059202
# 2         39.2   21.9038    69.3732              2013.0          2304.059202
# 3        135.0   23.8712    91.3602              2004.0           631.777928
# 4       1800.0   21.9603    82.4091              2015.0          1668.290000
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0          2420.393316          2414.072373          2453.936292
# 1          2420.393316          2414.072373          2453.936292
# 2          2420.393316          2414.072373          2453.936292
# 3           617.789264           843.747000           886.004428
# 4          3035.550000          5916.370000          6243.000000
#
#    generation_gwh_2017   gppd_idnr primary_fuel  \
# 0          2531.754458  WRI1020239        Solar
# 1          2531.754458  WRI1019881         Coal
# 2          2531.754458  WRI1026669         Wind
# 3           663.774500  IND0000001          Gas
# 4          5385.579736  IND0000002         Coal
#
#                                  source                    geolocation_source
# 0  National Renewable Energy Laboratory  National Renewable Energy Laboratory
# 1                  Ultratech Cement ltd                                   WRI
# 2                                   CDM                                   WRI
# 3         Central Electricity Authority                                   WRI
# 4         Central Electricity Authority                                   WRI

# %%
df1['primary_fuel'].value_counts()
# Out:
# Coal       259
# Hydro      250
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         21
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %%
sns.countplot(df1['primary_fuel'])
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# In the above plot, we can see that most of the primary fuel in power plant is coal and hydro are in 250 count and least one is nuclear.
#
# And here observe our target varaible data is imbalaced

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_col = cat_col.apply(le.fit_transform)

# %%
cat_col.head()
# Out:
#    gppd_idnr  primary_fuel  source  geolocation_source
# 0        658             6     109                   1
# 1        520             1     174                   2
# 2        854             7      21                   2
# 3          0             2      22                   2
# 4          1             1      22                   2

# %%
df1 = pd.concat([num_col,cat_col],axis = 1)
df1
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090              2013.0
# 2           39.2   21.9038    69.3732              2013.0
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 903       1600.0   16.2949    77.3568              2016.0
# 904          3.0   12.8932    78.1654              2013.0
# 905         25.5   15.2758    75.5811              2013.0
# 906         80.0   24.3500    73.7477              2013.0
# 907         16.5    9.9344    77.4768              2013.0
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0            2304.059202          2420.393316          2414.072373
# 1            2304.059202          2420.393316          2414.072373
# 2            2304.059202          2420.393316          2414.072373
# 3             631.777928           617.789264           843.747000
# 4            1668.290000          3035.550000          5916.370000
# ..                   ...                  ...                  ...
# 903          2304.059202          2420.393316             0.994875
# 904          2304.059202          2420.393316          2414.072373
# 905          2304.059202          2420.393316          2414.072373
# 906          2304.059202          2420.393316          2414.072373
# 907          2304.059202          2420.393316          2414.072373
#
#      generation_gwh_2016  generation_gwh_2017  gppd_idnr  primary_fuel  \
# 0            2453.936292          2531.754458        658             6
# 1            2453.936292          2531.754458        520             1
# 2            2453.936292          2531.754458        854             7
# 3             886.004428           663.774500          0             2
# 4            6243.000000          5385.579736          1             1
# ..                   ...                  ...        ...           ...
# 903           233.596650           865.400000        494             1
# 904          2453.936292          2531.754458        823             6
# 905          2453.936292          2531.754458        892             7
# 906          2453.936292          2531.754458        540             1
# 907          2453.936292          2531.754458        877             7
#
#      source  geolocation_source
# 0       109                   1
# 1       174                   2
# 2        21                   2
# 3        22                   2
# 4        22                   2
# ..      ...                 ...
# 903      22                   2
# 904      77                   0
# 905      21                   2
# 906      59                   2
# 907      21                   2
#
# [908 rows x 13 columns]

# %%
df1.dtypes
# Out:
# capacity_mw            float64
# latitude               float64
# longitude              float64
# commissioning_year     float64
# generation_gwh_2013    float64
# generation_gwh_2014    float64
# generation_gwh_2015    float64
# generation_gwh_2016    float64
# generation_gwh_2017    float64
# gppd_idnr                int32
# primary_fuel             int32
# source                   int32
# geolocation_source       int32
# dtype: object

# %%
df1.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   908.000000  908.000000  908.000000          908.000000
# mean    321.046378   21.084948   77.156237         2003.624449
# std     580.221767    6.107146    4.945215           15.238021
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.837500   17.057825   73.812975         1997.000000
# 50%      60.000000   21.278850   76.492900         2013.000000
# 75%     388.125000   25.183775   79.211600         2013.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# count           908.000000           908.000000           908.000000
# mean           2304.059202          2420.393316          2414.072373
# std            2465.930970          2665.360236          2860.146282
# min               0.000000             0.000000             0.000000
# 25%            1332.538825          1175.264825           874.205000
# 50%            2304.059202          2420.393316          2414.072373
# 75%            2304.059202          2420.393316          2414.072373
# max           27586.200000         28127.000000         30539.000000
#
#        generation_gwh_2016  generation_gwh_2017  gppd_idnr  primary_fuel  \
# count           908.000000           908.000000  908.00000    908.000000
# mean           2453.936292          2531.754458  453.50000      3.205947
# std            2878.730064          2923.041411  262.26132      2.281339
# min               0.000000             0.000000    0.00000      0.000000
# 25%             826.629750           852.438887  226.75000      1.000000
# 50%            2453.936292          2531.754458  453.50000      3.000000
# 75%            2453.936292          2531.754458  680.25000      6.000000
# max           30015.000000         35116.000000  907.00000      7.000000
#
#            source  geolocation_source
# count  908.000000          908.000000
# mean    43.823789            1.733480
# std     44.624092            0.676835
# min      0.000000            0.000000
# 25%     22.000000            2.000000
# 50%     22.000000            2.000000
# 75%     29.250000            2.000000
# max    190.000000            2.000000

# %% [markdown]
# # EDA

# %%
plt.figure(figsize = (15,10))
plotnumber = 1

for column in df1:
    if plotnumber<=15:
        ax = plt.subplot(5,3,plotnumber)
        sns.distplot(df1[column])
        plt.xlabel(column,fontsize = 10)
               
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here data is not normally distributed most of the columns has outliers

# %%
for i in df1.columns:
    plt.figure(figsize = (20,10))
    sns.barplot(x=df[i],y=df1.primary_fuel)

# %% [markdown]
# Relationship between feature and label variable observed

# %%
df1.value_counts()
# Out:
# capacity_mw  latitude  longitude  commissioning_year  generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  gppd_idnr  primary_fuel  source  geolocation_source
# 4760.00      24.0983   82.6719    2002.0              26761.390000         27594.000000         29047.000000         30015.000000         35116.000000         484        1             22      2                     1
# 23.10        14.6534   75.8613    2013.0              2304.059202          2420.393316          2414.072373          2453.936292          2531.754458          843        7             21      2                     1
# 25.20        19.0004   71.6917    2000.0              0.000000             0.000000             0.000000             0.000000             0.000000             42         5             22      2                     1
#              18.5309   72.9465    2013.0              2304.059202          2420.393316          2414.072373          2453.936292          2531.754458          653        5             76      2                     1
# 25.00        25.6732   76.1901    2013.0              2304.059202          2420.393316          2414.072373          2453.936292          2531.754458          530        1             3       2                     1
#                                                                                                                                                                                                                      ..
# 172.00       24.9174   75.5794    1968.0              507.897750           379.413400           515.509500           446.536100           376.368700           334        3             22      2                     1
# 166.50       12.9821   74.8496    2013.0              2304.059202          2420.393316          2414.072373          2453.936292          2531.754458          565        2             92      2                     1
# 165.00       10.0740   76.3188    1999.0              336.680000           145.560000           3.417200             0.000000             60.718000            64         2             22      2                     1
# 161.75       27.1858   95.3760    1990.0              494.983000           569.674000           487.339000           333.180000           306.396000           275        2             22      2                     1
# 0.00         12.8491   77.6752    2013.0              2304.059202          2420.393316          2414.072373          2453.936292          2531.754458          817        6             166     0                     1
# Length: 908, dtype: int64

# %%
df1.hist(bins = 5, figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'capacity_mw'}>,
#         <AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'commissioning_year'}>],
#        [<AxesSubplot:title={'center':'generation_gwh_2013'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2014'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2015'}>,
#         <AxesSubplot:title={'center':'generation_gwh_2016'}>],
#        [<AxesSubplot:title={'center':'generation_gwh_2017'}>,
#         <AxesSubplot:title={'center':'gppd_idnr'}>,
#         <AxesSubplot:title={'center':'primary_fuel'}>,
#         <AxesSubplot:title={'center':'source'}>],
#        [<AxesSubplot:title={'center':'geolocation_source'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# We will plot and see how the data has been distributed using histogram plot here to visualize the data.
#
# "capacity_mw","generation_gwh_2013","generation_gwh_2014","generation_gwh_2015","generation_gwh_2016","generation_gwh_2017","source" has skewness in right side and "commissioning_year" has skewness on left side.
#
# We will treat ouliers.

# %%
#visualize correlation 
plt.figure(figsize=(22,7))
df1.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#heat map
fig, ax = plt.subplots(figsize=(17,13))
sns.heatmap(df1.corr(),cmap = 'rainbow', annot=True, linewidths=.5, ax=ax)
plt.show()

# %%
#seperate target and labels
Y = df1['primary_fuel']
X = df1.drop(columns = ['primary_fuel'])

# %%
#visulizing relationship
plt.figure(figsize = (20,10))
plotnumber = 1

for column in X:
    if plotnumber<=18:
        ax = plt.subplot(3,6,plotnumber)
        plt.scatter(X[column],Y)
        plt.xlabel(column,fontsize = 20)
        plt.ylabel('primary_fuel',fontsize = 20)
               
    plotnumber+=1
plt.tight_layout()

# %%
#check skewness
num_col.skew()
# Out:
# capacity_mw            3.193257
# latitude              -0.093609
# longitude              1.118449
# commissioning_year    -1.779021
# generation_gwh_2013    5.241491
# generation_gwh_2014    5.041961
# generation_gwh_2015    5.367370
# generation_gwh_2016    5.071758
# generation_gwh_2017    5.111938
# dtype: float64

# %% [markdown]
# we can see here most of the columns are skewed
#
# Outliers Handling using Box Plot
#
# We applied outliers skewness to numerical data only.

# %%
#use boxplot
fig,ax = plt.subplots(ncols=3,nrows=3,figsize=(20,15))
index=0
ax = ax.flatten()

for col, value in num_col.items():
    if col !='type':
        sns.boxplot(y=col,data=num_col,ax=ax[index])
        index+= 1

# %%
from scipy.stats import zscore
z=zscore(num_col)
z
# Out:
# array([[-5.49310543e-01,  1.16304149e+00, -7.92219230e-01, ...,
#          0.00000000e+00, -1.58055100e-16, -1.55659091e-16],
#        [-3.84627594e-01,  6.03126329e-01, -5.15375049e-01, ...,
#          0.00000000e+00, -1.58055100e-16, -1.55659091e-16],
#        [-4.86024006e-01,  1.34154785e-01, -1.57471932e+00, ...,
#          0.00000000e+00, -1.58055100e-16, -1.55659091e-16],
#        ...,
#        [-5.09648681e-01, -9.51729370e-01, -3.18692869e-01, ...,
#          0.00000000e+00, -1.58055100e-16, -1.55659091e-16],
#        [-4.15667312e-01,  5.34922712e-01, -6.89639387e-01, ...,
#          0.00000000e+00, -1.58055100e-16, -1.55659091e-16],
#        [-5.25168540e-01, -1.82682618e+00,  6.48586281e-02, ...,
#          0.00000000e+00, -1.58055100e-16, -1.55659091e-16]])

# %%
threshold = 3
print (np.where(z>3))
# Out:
# (array([ 15,  15,  15,  15, 144, 144, 144, 144, 144, 144, 159, 159, 180,
#        184, 210, 210, 210, 210, 210, 210, 245, 309, 309, 309, 309, 309,
#        309, 324, 334, 341, 361, 364, 365, 365, 365, 365, 365, 365, 376,
#        417, 428, 483, 494, 494, 494, 494, 494, 494, 495, 495, 495, 495,
#        495, 495, 500, 520, 533, 639, 649, 649, 649, 649, 649, 649, 658,
#        658, 658, 658, 658, 658, 696, 696, 696, 696, 696, 722, 722, 722,
#        722, 725, 725, 725, 725, 725, 727, 727, 727, 727, 727, 727, 787,
#        787, 787, 787, 787, 787, 789, 809, 809, 809, 809, 809, 819, 881,
#        881, 881, 881, 881, 881], dtype=int64), array([0, 6, 7, 8, 0, 4, 5, 6, 7, 8, 4, 5, 2, 2, 0, 4, 5, 6, 7, 8, 2, 0,
#        4, 5, 6, 7, 8, 2, 2, 2, 2, 0, 0, 4, 5, 6, 7, 8, 0, 2, 2, 0, 0, 4,
#        5, 6, 7, 8, 0, 4, 5, 6, 7, 8, 2, 2, 4, 2, 0, 4, 5, 6, 7, 8, 0, 4,
#        5, 6, 7, 8, 0, 5, 6, 7, 8, 4, 5, 6, 7, 4, 5, 6, 7, 8, 0, 4, 5, 6,
#        7, 8, 0, 4, 5, 6, 7, 8, 0, 0, 5, 6, 7, 8, 2, 0, 4, 5, 6, 7, 8],
#       dtype=int64))

# %%
df_new = num_col [(z<3).all(axis = 1)]

# %%
df1.shape
# Out:
# (908, 13)

# %%
df_new.shape
# Out:
# (873, 9)

# %%
#data loss
(908-858)/908*100
# Out:
# 5.506607929515418

# %% [markdown]
# here we lossing 6% of data usiing zscore ok lets move to check the skewness and if any skewness more than +-0.5,we will remove it

# %%
df_new.skew()
# Out:
# capacity_mw            2.028609
# latitude              -0.059916
# longitude              0.975934
# commissioning_year    -1.794529
# generation_gwh_2013    1.525960
# generation_gwh_2014    1.438574
# generation_gwh_2015    1.326746
# generation_gwh_2016    1.352260
# generation_gwh_2017    1.248729
# dtype: float64

# %% [markdown]
# We can see that most of the columns has skewed and so we apply the power_transform method

# %%
from sklearn.preprocessing import power_transform 
df_New=power_transform(df_new)
df_New=pd.DataFrame(df_New,columns=num_col.columns)

# %%
df_New.skew()
# Out:
# capacity_mw            0.016618
# latitude              -0.068177
# longitude              0.032591
# commissioning_year    -1.173601
# generation_gwh_2013   -0.184121
# generation_gwh_2014   -0.262776
# generation_gwh_2015   -0.324819
# generation_gwh_2016   -0.324363
# generation_gwh_2017   -0.351565
# dtype: float64

# %% [markdown]
# skewness is removed

# %%
df_New.head()
# Out:
#    capacity_mw  latitude  longitude  commissioning_year  generation_gwh_2013  \
# 0    -1.683292  1.162862  -0.809358            0.464690             0.326417
# 1     0.242116  0.610344  -0.401355            0.663019             0.326417
# 2    -0.259030  0.146820  -2.243330            0.663019             0.326417
# 3     0.415621  0.465478   2.296494           -0.162295            -1.037490
# 4     1.770045  0.155976   1.253856            0.870598            -0.114096
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0             0.349313             0.376193             0.379570
# 1             0.349313             0.376193             0.379570
# 2             0.349313             0.376193             0.379570
# 3            -1.020177            -0.702834            -0.653926
# 4             0.695439             1.919461             1.952437
#
#    generation_gwh_2017
# 0             0.379490
# 1             0.379490
# 2             0.379490
# 3            -0.871823
# 4             1.577815

# %%
df2 = pd.concat([df_New,cat_col],axis = 1)
df2
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0      -1.683292  1.162862  -0.809358            0.464690
# 1       0.242116  0.610344  -0.401355            0.663019
# 2      -0.259030  0.146820  -2.243330            0.663019
# 3       0.415621  0.465478   2.296494           -0.162295
# 4       1.770045  0.155976   1.253856            0.870598
# ..           ...       ...        ...                 ...
# 903          NaN       NaN        NaN                 NaN
# 904          NaN       NaN        NaN                 NaN
# 905          NaN       NaN        NaN                 NaN
# 906          NaN       NaN        NaN                 NaN
# 907          NaN       NaN        NaN                 NaN
#
#      generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# 0               0.326417             0.349313             0.376193
# 1               0.326417             0.349313             0.376193
# 2               0.326417             0.349313             0.376193
# 3              -1.037490            -1.020177            -0.702834
# 4              -0.114096             0.695439             1.919461
# ..                   ...                  ...                  ...
# 903                  NaN                  NaN                  NaN
# 904                  NaN                  NaN                  NaN
# 905                  NaN                  NaN                  NaN
# 906                  NaN                  NaN                  NaN
# 907                  NaN                  NaN                  NaN
#
#      generation_gwh_2016  generation_gwh_2017  gppd_idnr  primary_fuel  \
# 0               0.379570             0.379490        658             6
# 1               0.379570             0.379490        520             1
# 2               0.379570             0.379490        854             7
# 3              -0.653926            -0.871823          0             2
# 4               1.952437             1.577815          1             1
# ..                   ...                  ...        ...           ...
# 903                  NaN                  NaN        494             1
# 904                  NaN                  NaN        823             6
# 905                  NaN                  NaN        892             7
# 906                  NaN                  NaN        540             1
# 907                  NaN                  NaN        877             7
#
#      source  geolocation_source
# 0       109                   1
# 1       174                   2
# 2        21                   2
# 3        22                   2
# 4        22                   2
# ..      ...                 ...
# 903      22                   2
# 904      77                   0
# 905      21                   2
# 906      59                   2
# 907      21                   2
#
# [908 rows x 13 columns]

# %%
df2 = df2.dropna()
df2 = df2.reset_index(drop= True)

# %%
df2.shape
# Out:
# (873, 13)

# %%
x = df2.drop(columns = ['primary_fuel'],axis = 1)
y = df2['primary_fuel']

# %%
x.head()
# Out:
#    capacity_mw  latitude  longitude  commissioning_year  generation_gwh_2013  \
# 0    -1.683292  1.162862  -0.809358            0.464690             0.326417
# 1     0.242116  0.610344  -0.401355            0.663019             0.326417
# 2    -0.259030  0.146820  -2.243330            0.663019             0.326417
# 3     0.415621  0.465478   2.296494           -0.162295            -1.037490
# 4     1.770045  0.155976   1.253856            0.870598            -0.114096
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0             0.349313             0.376193             0.379570
# 1             0.349313             0.376193             0.379570
# 2             0.349313             0.376193             0.379570
# 3            -1.020177            -0.702834            -0.653926
# 4             0.695439             1.919461             1.952437
#
#    generation_gwh_2017  gppd_idnr  source  geolocation_source
# 0             0.379490        658     109                   1
# 1             0.379490        520     174                   2
# 2             0.379490        854      21                   2
# 3            -0.871823          0      22                   2
# 4             1.577815          1      22                   2

# %%
x.shape
# Out:
# (873, 12)

# %%
y
# Out:
# 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 868    1
# 869    2
# 870    3
# 871    1
# 872    1
# Name: primary_fuel, Length: 873, dtype: int32

# %% [markdown]
# # Data Imbalanced

# %%
#let’s visualize the count of target variable using Seaborn
sns.countplot(df1['primary_fuel'])
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# We can see that classes are imbalanced and I am using SMOTE() technique to balance the imbalanced dataset,

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x= pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
x , y = SM.fit_resample(x,Y)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %%
y.value_counts()
# Out:
# 7    259
# 5    259
# 3    259
# 1    259
# 6    259
# 4    259
# 2    259
# 0    259
# Name: primary_fuel, dtype: int64

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,classification_report
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score,roc_curve
import scikitplot as skplt

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20, random_state=40)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((1657, 12), (415, 12), (1657,), (415,))

# %%
#Train result
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred =KNN .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#Test result
KNN = KNeighborsClassifier()
KNN.fit(x_train, y_train)
y_pred =KNN .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       213
#            1       0.89      0.75      0.81       206
#            2       0.86      0.89      0.87       196
#            3       0.94      0.79      0.86       206
#            4       0.91      1.00      0.96       204
#            5       0.89      1.00      0.94       204
#            6       1.00      1.00      1.00       210
#            7       0.99      1.00      1.00       218
#
#     accuracy                           0.93      1657
#    macro avg       0.92      0.92      0.92      1657
# weighted avg       0.93      0.93      0.92      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84        46
#            1       0.75      0.51      0.61        53
#            2       0.82      0.86      0.84        63
#            3       0.82      0.60      0.70        53
#            4       0.84      0.98      0.91        55
#            5       0.83      0.96      0.89        55
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        41
#
#     accuracy                           0.85       415
#    macro avg       0.85      0.86      0.85       415
# weighted avg       0.85      0.85      0.84       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",KNN.score(x_train,y_train))
print("Test accuracy::",KNN.score(x_test,y_test))
# Out:
# Training accuracy:: 0.9251659625829813
# Test accuracy:: 0.8506024096385543

# %%
print(cross_val_score(KNN,x,y,cv=3).mean())
# Out:
# 0.8595587155770885

# %%
#ROC CURVE of KNN:
prob1 = KNN.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob1)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - KNN')
plt.show()

# %%
#train result
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
y_pred =RFC .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
y_pred =RFC .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       213
#            1       1.00      1.00      1.00       206
#            2       1.00      1.00      1.00       196
#            3       1.00      1.00      1.00       206
#            4       1.00      1.00      1.00       204
#            5       1.00      1.00      1.00       204
#            6       1.00      1.00      1.00       210
#            7       1.00      1.00      1.00       218
#
#     accuracy                           1.00      1657
#    macro avg       1.00      1.00      1.00      1657
# weighted avg       1.00      1.00      1.00      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        46
#            1       0.80      0.70      0.75        53
#            2       0.86      0.89      0.88        63
#            3       0.87      0.87      0.87        53
#            4       0.92      1.00      0.96        55
#            5       0.96      0.93      0.94        55
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        41
#
#     accuracy                           0.91       415
#    macro avg       0.92      0.92      0.92       415
# weighted avg       0.91      0.91      0.91       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",RFC.score(x_train,y_train))
print("Test accuracy::",RFC.score(x_test,y_test))
# Out:
# Training accuracy:: 1.0
# Test accuracy:: 0.9132530120481928

# %%
print(cross_val_score(RFC,x,y,cv=3).mean())
# Out:
# 0.9102407069499501

# %%
#ROC CURVE of RFC:
prob2 = RFC.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob2)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - RFC')
plt.show()

# %%
#train result
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(x_train, y_train)
y_pred =DecisionTree .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))

#test result
DecisionTree = DecisionTreeClassifier()
DecisionTree.fit(x_train, y_train)
y_pred =DecisionTree .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       213
#            1       1.00      1.00      1.00       206
#            2       1.00      1.00      1.00       196
#            3       1.00      1.00      1.00       206
#            4       1.00      1.00      1.00       204
#            5       1.00      1.00      1.00       204
#            6       1.00      1.00      1.00       210
#            7       1.00      1.00      1.00       218
#
#     accuracy                           1.00      1657
#    macro avg       1.00      1.00      1.00      1657
# weighted avg       1.00      1.00      1.00      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        46
#            1       0.62      0.64      0.63        53
#            2       0.89      0.86      0.87        63
#            3       0.81      0.79      0.80        53
#            4       0.93      0.91      0.92        55
#            5       0.89      0.91      0.90        55
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        41
#
#     accuracy                           0.88       415
#    macro avg       0.88      0.88      0.88       415
# weighted avg       0.88      0.88      0.88       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",DecisionTree.score(x_train,y_train))
print("Test accuracy::",DecisionTree.score(x_test,y_test))
# Out:
# Training accuracy:: 1.0
# Test accuracy:: 0.8771084337349397

# %%
print(cross_val_score(DecisionTree,x,y,cv=3).mean())
# Out:
# 0.8528143067877543

# %%
#ROC CURVE of DecisionTree:
prob3 = DecisionTree.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob3)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - DecisionTree')
plt.show()

# %%
#train result
LR = LogisticRegression()
LR.fit(x_train, y_train)
y_pred =LR .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
LR = LogisticRegression()
LR.fit(x_train, y_train)
y_pred =LR .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84       213
#            1       0.74      0.53      0.62       206
#            2       0.65      0.57      0.61       196
#            3       0.66      0.65      0.65       206
#            4       0.79      0.83      0.81       204
#            5       0.75      0.75      0.75       204
#            6       1.00      0.96      0.98       210
#            7       0.93      1.00      0.96       218
#
#     accuracy                           0.79      1657
#    macro avg       0.78      0.78      0.78      1657
# weighted avg       0.78      0.79      0.78      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.67      0.96      0.79        46
#            1       0.65      0.38      0.48        53
#            2       0.62      0.56      0.59        63
#            3       0.48      0.47      0.48        53
#            4       0.76      0.87      0.81        55
#            5       0.75      0.75      0.75        55
#            6       1.00      1.00      1.00        49
#            7       0.95      1.00      0.98        41
#
#     accuracy                           0.73       415
#    macro avg       0.73      0.75      0.73       415
# weighted avg       0.72      0.73      0.72       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",LR.score(x_train,y_train))
print("Test accuracy::",LR.score(x_test,y_test))
# Out:
# Training accuracy:: 0.7851538925769463
# Test accuracy:: 0.7301204819277108

# %%
print(cross_val_score(LR,x,y,cv=3).mean())
# Out:
# 0.7307018463754132

# %%
#ROC CURVE of LR:
prob4 = LR.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob4)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - LR')
plt.show()

# %% [markdown]
# # ENSEMBLE TECHNIQUES

# %%
#train result
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_pred =adb .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
adb = AdaBoostClassifier()
adb.fit(x_train, y_train)
y_pred =adb .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.98      0.44       213
#            1       0.45      0.04      0.08       206
#            2       0.00      0.00      0.00       196
#            3       0.64      0.54      0.59       206
#            4       0.64      0.92      0.75       204
#            5       0.00      0.00      0.00       204
#            6       1.00      0.96      0.98       210
#            7       1.00      1.00      1.00       218
#
#     accuracy                           0.57      1657
#    macro avg       0.50      0.56      0.48      1657
# weighted avg       0.51      0.57      0.49      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.20      0.96      0.33        46
#            1       0.67      0.08      0.14        53
#            2       0.00      0.00      0.00        63
#            3       0.72      0.40      0.51        53
#            4       0.75      0.98      0.85        55
#            5       0.00      0.00      0.00        55
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        41
#
#     accuracy                           0.51       415
#    macro avg       0.54      0.55      0.48       415
# weighted avg       0.52      0.51      0.45       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",adb.score(x_train,y_train))
print("Test accuracy::",adb.score(x_test,y_test))
# Out:
# Training accuracy:: 0.5654797827398914
# Test accuracy:: 0.5132530120481927

# %%
print(cross_val_score(adb,x,y,cv=10).mean())
# Out:
# 0.5106094388703084

# %%
#ROC CURVE of adb:
prob5 = adb.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob5)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - adb')
plt.show()

# %%
#train result
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
y_pred =gbc .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print( skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
gbc = GradientBoostingClassifier()
gbc.fit(x_train, y_train)
y_pred =gbc .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print( skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       213
#            1       1.00      1.00      1.00       206
#            2       0.99      0.99      0.99       196
#            3       1.00      1.00      1.00       206
#            4       1.00      1.00      1.00       204
#            5       1.00      1.00      1.00       204
#            6       1.00      1.00      1.00       210
#            7       1.00      1.00      1.00       218
#
#     accuracy                           1.00      1657
#    macro avg       1.00      1.00      1.00      1657
# weighted avg       1.00      1.00      1.00      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        46
#            1       0.73      0.68      0.71        53
#            2       0.86      0.90      0.88        63
#            3       0.87      0.77      0.82        53
#            4       0.87      0.98      0.92        55
#            5       0.96      0.95      0.95        55
#            6       1.00      1.00      1.00        49
#            7       0.98      1.00      0.99        41
#
#     accuracy                           0.90       415
#    macro avg       0.90      0.90      0.90       415
# weighted avg       0.90      0.90      0.89       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",gbc.score(x_train,y_train))
print("Test accuracy::",gbc.score(x_test,y_test))
# Out:
# Training accuracy:: 0.9987929993964997
# Test accuracy:: 0.8963855421686747

# %%
print(cross_val_score(gbc,x,y,cv=5).mean())
# Out:
# 0.906391944589954

# %%
#ROC CURVE of gbc:
prob6 = gbc.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob1)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - gbc')
plt.show()

# %%
#train result
bgc = BaggingClassifier()
bgc.fit(x_train, y_train)
y_pred =bgc .predict(x_train)
accuracy = classification_report(y_train, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_train, y_pred))


#test result
bgc = BaggingClassifier()
bgc.fit(x_train, y_train)
y_pred =bgc .predict(x_test)
accuracy = classification_report(y_test, y_pred)
print(accuracy)
print(skplt.metrics.plot_confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       213
#            1       1.00      0.99      0.99       206
#            2       0.98      0.98      0.98       196
#            3       1.00      0.98      0.99       206
#            4       1.00      1.00      1.00       204
#            5       0.99      1.00      1.00       204
#            6       1.00      1.00      1.00       210
#            7       1.00      1.00      1.00       218
#
#     accuracy                           0.99      1657
#    macro avg       0.99      0.99      0.99      1657
# weighted avg       0.99      0.99      0.99      1657
#
# AxesSubplot(0.125,0.125;0.62x0.755)
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        46
#            1       0.68      0.64      0.66        53
#            2       0.86      0.89      0.88        63
#            3       0.84      0.81      0.83        53
#            4       0.90      0.95      0.92        55
#            5       0.95      0.95      0.95        55
#            6       1.00      1.00      1.00        49
#            7       1.00      1.00      1.00        41
#
#     accuracy                           0.89       415
#    macro avg       0.90      0.90      0.90       415
# weighted avg       0.89      0.89      0.89       415
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
print("Training accuracy::",bgc.score(x_train,y_train))
print("Test accuracy::",bgc.score(x_test,y_test))
# Out:
# Training accuracy:: 0.9987929993964997
# Test accuracy:: 0.891566265060241

# %%
print(cross_val_score(bgc,x,y,cv=5).mean())
# Out:
# 0.9044595774401956

# %%
#ROC CURVE of bgc:
prob7 = bgc.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob1)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC - bgc')
plt.show()

# %% [markdown]
# As per the CV Score and F1 score accuracy, less difference of model is choosen as best model. So as per that , RandomForestClassifier is the best model. We will do improve our accuracy of the model through Hyper-parameter tuning.

# %% [markdown]
# # Hyper Parameter Tuning

# %%
params = {'n_estimators' : [40,60,80,100] ,
         'max_depth': [4,8,12,16,20],
         'criterion' : ['gini','entropy'],
         'min_samples_leaf' : [2,4,6,8,10], 
         'min_samples_split' : [3,6,9,12,15] }

# %%
model=RandomForestClassifier()

# %%
grid_clf=GridSearchCV(model,params,verbose=4,refit=True,cv = 5,n_jobs = -1)

# %%
grid_clf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 8, 12, 16, 20],
#                          'min_samples_leaf': [2, 4, 6, 8, 10],
#                          'min_samples_split': [3, 6, 9, 12, 15],
#                          'n_estimators': [40, 60, 80, 100]},
#              verbose=4)

# %%
clf=grid_clf.best_estimator_
print(clf)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=20, min_samples_leaf=2,
#                        min_samples_split=3, n_estimators=60)

# %%
clf=grid_clf.best_params_
print(clf)
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 60}

# %%
clf=grid_clf.best_score_
print(clf)
# Out:
# 0.9148873439376842

# %%
clf = RandomForestClassifier(n_estimators=80 , criterion = 'entropy', max_depth = 20, 
                               min_samples_leaf =2,min_samples_split =6)
clf.fit(x_train,y_train)
clf.score(x_test,y_test)
# Out:
# 0.8987951807228916

# %%
y_pred=clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8987951807228916

# %%
skplt.metrics.plot_confusion_matrix(y_test,y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted label', ylabel='True label'>

# %%
print(cross_val_score(RFC,x,y,cv=3).mean())
# Out:
# 0.9107210022581569

# %%
#ROC CURVE of clf:
prob2 = clf.predict_proba(x_test)
skplt.metrics.plot_roc(y_test,prob2)


plt.xlabel("FalsePositiveRate")
plt.ylabel("TruePositiveRate")
plt.title('AUC ROC -RFC clf')
plt.show()

# %% [markdown]
# As we notice after HYPER PARAMETER TUNING models accuracy score is achieved 91% accuracy
#
# ROC Curve for final Model:
#
# Random forest is a flexible, easy to use machine learning algorithm that produces, even without hyper-parameter tuning, a great result most of the time. It is also one of the most used algorithms,it can be used for both classification and regression tasks.random forest builds multiple decision trees and merges them together to get a more accurate and stable prediction.The algorithm is also a great choice for anyone who needs to develop a model quickly. On top of that, it provides a pretty good indicator of the importance it assigns to our features.

# %%
import joblib
joblib.dump(clf,'Global_Power_Plant')
# Out:
# ['Global_Power_Plant']

# %% [markdown]
# As per the problem statement we have two target variable, Let me check with target variable - capacity_mw and see the accuracy score and this is Regression Model

# %%
df2.head()
# Out:
#    capacity_mw  latitude  longitude  commissioning_year  generation_gwh_2013  \
# 0    -1.683292  1.162862  -0.809358            0.464690             0.326417
# 1     0.242116  0.610344  -0.401355            0.663019             0.326417
# 2    -0.259030  0.146820  -2.243330            0.663019             0.326417
# 3     0.415621  0.465478   2.296494           -0.162295            -1.037490
# 4     1.770045  0.155976   1.253856            0.870598            -0.114096
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0             0.349313             0.376193             0.379570
# 1             0.349313             0.376193             0.379570
# 2             0.349313             0.376193             0.379570
# 3            -1.020177            -0.702834            -0.653926
# 4             0.695439             1.919461             1.952437
#
#    generation_gwh_2017  gppd_idnr  primary_fuel  source  geolocation_source
# 0             0.379490        658             6     109                   1
# 1             0.379490        520             1     174                   2
# 2             0.379490        854             7      21                   2
# 3            -0.871823          0             2      22                   2
# 4             1.577815          1             1      22                   2

# %%
#lets seperate target and label columns
X = df2.drop(columns = ['capacity_mw'],axis = 1)
y = df2['capacity_mw']

# %%
X.head()
# Out:
#    latitude  longitude  commissioning_year  generation_gwh_2013  \
# 0  1.162862  -0.809358            0.464690             0.326417
# 1  0.610344  -0.401355            0.663019             0.326417
# 2  0.146820  -2.243330            0.663019             0.326417
# 3  0.465478   2.296494           -0.162295            -1.037490
# 4  0.155976   1.253856            0.870598            -0.114096
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0             0.349313             0.376193             0.379570
# 1             0.349313             0.376193             0.379570
# 2             0.349313             0.376193             0.379570
# 3            -1.020177            -0.702834            -0.653926
# 4             0.695439             1.919461             1.952437
#
#    generation_gwh_2017  gppd_idnr  primary_fuel  source  geolocation_source
# 0             0.379490        658             6     109                   1
# 1             0.379490        520             1     174                   2
# 2             0.379490        854             7      21                   2
# 3            -0.871823          0             2      22                   2
# 4             1.577815          1             1      22                   2

# %%
scaler = StandardScaler()
x = scaler.fit_transform(X)

# %%
x
# Out:
# array([[ 1.16286224, -0.80935738,  0.46469006, ...,  1.23496695,
#          1.47529589, -1.07961988],
#        [ 0.61034423, -0.40135433,  0.66301935, ..., -0.97159496,
#          2.94321917,  0.39535376],
#        [ 0.14681982, -2.24332938,  0.66301935, ...,  1.67627933,
#         -0.51204641,  0.39535376],
#        ...,
#        [-0.92961982, -0.13731502,  0.66301935, ..., -0.08897019,
#         -0.48946297,  0.39535376],
#        [ 0.54297735, -0.65293513,  0.66301935, ..., -0.97159496,
#          3.07871978,  0.39535376],
#        [-1.8013496 ,  0.32335919,  0.66301935, ..., -0.97159496,
#          3.07871978,  0.39535376]])

# %%
#split the train test data
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.25, random_state = 128)

# %%
#check the shape of train test split
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((654, 12), (219, 12), (654,), (219,))

# %%
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
kn = KNeighborsRegressor()
ab = AdaBoostRegressor()
rf = RandomForestRegressor()
xgb = XGBRegressor()
svm = SVR()
dt = DecisionTreeRegressor()

# %%
models =SVR() ,RandomForestRegressor(),XGBRegressor(), KNeighborsRegressor(),AdaBoostRegressor(),DecisionTreeRegressor()

# %%
#coefficient matrix
#MAE MSE RMSE Using with metrics 
maelist=[]
mselist=[]
rmselist=[]
r2list=[]
def create_model(model):
    m=model
    m.fit(x_train,y_train)
    p=m.predict(x_test)
    
    mae=mean_absolute_error(p,y_test)
    mse=mean_squared_error(p,y_test)   
    rmse=np.sqrt(mean_squared_error(p,y_test))
    r2=r2_score(y_test,p)
    
    maelist.append(mae)
    mselist.append(mse)
    rmselist.append(rmse)
    r2list.append(r2)
    
    print(m)
    print('Mean absolute error',mae)
    print('Mean squared error',mse)
    print('Root Mean squared error',rmse)
    print('R2 Score',r2)
    print('---------------------------------------------------------------------------------------------------------')

# %%
for i in models:
    create_model(i)
# Out:
# SVR()
# Mean absolute error 0.58379945903443
# Mean squared error 0.5977382478367843
# Root Mean squared error 0.7731353360420052
# R2 Score 0.4554995873269938
# ---------------------------------------------------------------------------------------------------------
# RandomForestRegressor()
# Mean absolute error 0.36814401078317793
# Mean squared error 0.2703363041335533
# Root Mean squared error 0.5199387503673422
# R2 Score 0.7537413245782318
# ---------------------------------------------------------------------------------------------------------
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)
# Mean absolute error 0.419150551524284
# Mean squared error 0.3026551904277388
# Root Mean squared error 0.550141064116958
# R2 Score 0.7243009349294149
# ---------------------------------------------------------------------------------------------------------
# KNeighborsRegressor()
# Mean absolute error 0.6054818846050946
# Mean squared error 0.6613556464560544
# Root Mean squared error 0.813237755183596
# R2 Score 0.39754830191613577
# ---------------------------------------------------------------------------------------------------------
# AdaBoostRegressor()
# Mean absolute error 0.4160879148768451
# Mean squared error 0.3035955153373784
# Root Mean squared error 0.5509950229696984
# R2 Score 0.723444360495374
# ---------------------------------------------------------------------------------------------------------
# DecisionTreeRegressor()
# Mean absolute error 0.46042829357720716
# Mean squared error 0.413678256516857
# Root Mean squared error 0.6431782463025759
# R2 Score 0.6231661898791802
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Cross Validation

# %%
#do cross validation for score
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# 0.7378605842093363

# %%
print(cross_val_score(kn,x,y,cv=5).mean())
# Out:
# 0.37156577424796944

# %%
print(cross_val_score(ab,x,y,cv=5).mean())
# Out:
# 0.6992559640636115

# %%
print(cross_val_score(xgb,x,y,cv=5).mean())
# Out:
# 0.7133674274178862

# %%
print(cross_val_score(svm,x,y,cv=5).mean())
# Out:
# 0.5134833683623244

# %%
print(cross_val_score(dt,x,y,cv=5).mean())
# Out:
# 0.5545807535651058

# %%
print('Minimum Mean Absolute error is shown by ',models[maelist.index(min(maelist))],min(maelist))
print('Minimum Mean squared error is shown by ',models[mselist.index(min(mselist))],min(mselist))
print('Minimum Root Mean squared error is shown by ',models[rmselist.index(min(rmselist))],min(rmselist))
print('Maximun R2 Score is shown by ',models[r2list.index(max(r2list))],max(r2list))
print(cross_val_score(rf,x,y,cv=5).mean())
# Out:
# Minimum Mean Absolute error is shown by  RandomForestRegressor() 0.36814401078317793
# Minimum Mean squared error is shown by  RandomForestRegressor() 0.2703363041335533
# Minimum Root Mean squared error is shown by  RandomForestRegressor() 0.5199387503673422
# Maximun R2 Score is shown by  RandomForestRegressor() 0.7537413245782318
# 0.7404481997830048

# %% [markdown]
# Compare CV Score and r2 score is having less difference and the model is less difference is considered as best model.
#
# As per this, RandomForestRegressor model is considered as best model.
#
# After that,tuning the hyper parameter to check the model accuracy further.
#
# Applying hyper parameter tuning

# %%
from scipy.stats import randint

# %%
model=RandomForestRegressor()
param_grid={ 
            "n_estimators"      : [10,20,30],
            "max_features"      : ["auto", "sqrt", "log2"],
            "min_samples_split" : [2,4,8],
            "bootstrap": [True, False],
            }
regression=GridSearchCV(model,param_grid,cv=10)

# %%
regression.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [2, 4, 8],
#                          'n_estimators': [10, 20, 30]})

# %%
rf_regres=regression.best_estimator_
print(rf_regres)
# Out:
# RandomForestRegressor(max_features='sqrt', min_samples_split=4, n_estimators=10)

# %%
rf_regres=regression.best_params_
print(rf_regres)
# Out:
# {'bootstrap': True, 'max_features': 'sqrt', 'min_samples_split': 4, 'n_estimators': 10}

# %%
rf_regres=regression.best_score_
print(rf_regres)
# Out:
# 0.7373954597223361

# %%
rf_regres=regression.predict(x_test)

# %%
mae=mean_absolute_error(rf_regres,y_test)
mse=mean_squared_error(rf_regres,y_test)
rmse=np.sqrt(mean_squared_error(rf_regres,y_test))
r2=r2_score(y_test,rf_regres)

# %%
print('Mean absolute error',mae)
print('Mean squared error',mse)
print('Root Mean squared error',rmse)
print('R2 Score',r2)
# Out:
# Mean absolute error 0.38960997584485624
# Mean squared error 0.28636025939486953
# Root Mean squared error 0.5351263957186839
# R2 Score 0.7391445503480125

# %%
plt.scatter(y_test,rf_regres)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %% [markdown]
# # Saving Model

# %%
import joblib
joblib.dump(rf_regres,"Global_Power_Plant_regression.pkl")
# Out:
# ['Global_Power_Plant_regression.pkl']
